# %%
import nltk
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

from sklearn.feature_extraction.text import TfidfVectorizer


nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asmit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\asmit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\asmit\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asmit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\asmit\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# ...

# %%
document = """
Text analytics is the process of extracting meaningful information from text data.
It is widely used in natural language processing, sentiment analysis, document classification,
and information retrieval systems.
"""
print("Original Document:")
print(document)
# Out:
# Original Document:
#
# Text analytics is the process of extracting meaningful information from text data.
# It is widely used in natural language processing, sentiment analysis, document classification,
# and information retrieval systems.

# %%
tokens = word_tokenize(document)

print("\nTokens:")
print(tokens)
# Out:
# Tokens:
# ['Text', 'analytics', 'is', 'the', 'process', 'of', 'extracting', 'meaningful', 'information', 'from', 'text', 'data', '.', 'It', 'is', 'widely', 'used', 'in', 'natural', 'language', 'processing', ',', 'sentiment', 'analysis', ',', 'document', 'classification', ',', 'and', 'information', 'retrieval', 'systems', '.']

# %%
pos_tags = pos_tag(tokens)

print("\nPOS Tags:")
print(pos_tags)
# Out:
# POS Tags:
# [('Text', 'NN'), ('analytics', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('extracting', 'VBG'), ('meaningful', 'JJ'), ('information', 'NN'), ('from', 'IN'), ('text', 'NN'), ('data', 'NNS'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('widely', 'RB'), ('used', 'VBN'), ('in', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), (',', ','), ('sentiment', 'NN'), ('analysis', 'NN'), (',', ','), ('document', 'NN'), ('classification', 'NN'), (',', ','), ('and', 'CC'), ('information', 'NN'), ('retrieval', 'NN'), ('systems', 'NNS'), ('.', '.')]

# %%
stop_words = set(stopwords.words('english'))

filtered_tokens = []

for word in tokens:
    if word.lower() not in stop_words and word.isalpha():
        filtered_tokens.append(word)

print("\nTokens After Stop Words Removal:")
print(filtered_tokens)
# Out:
# Tokens After Stop Words Removal:
# ['Text', 'analytics', 'process', 'extracting', 'meaningful', 'information', 'text', 'data', 'widely', 'used', 'natural', 'language', 'processing', 'sentiment', 'analysis', 'document', 'classification', 'information', 'retrieval', 'systems']

# %%
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_tokens:
    stemmed_words.append(stemmer.stem(word))

print("\nStemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['text', 'analyt', 'process', 'extract', 'meaning', 'inform', 'text', 'data', 'wide', 'use', 'natur', 'languag', 'process', 'sentiment', 'analysi', 'document', 'classif', 'inform', 'retriev', 'system']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in filtered_tokens:
    lemmatized_words.append(lemmatizer.lemmatize(word.lower()))

print("\nLemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['text', 'analytics', 'process', 'extracting', 'meaningful', 'information', 'text', 'data', 'widely', 'used', 'natural', 'language', 'processing', 'sentiment', 'analysis', 'document', 'classification', 'information', 'retrieval', 'system']

# %%
documents = [
    "Text analytics extracts meaningful information from text data.",
    "Natural language processing is used for text classification.",
    "Information retrieval systems search relevant documents."
]

# %%
vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print("\nTF-IDF Representation:")
display(tfidf_df)
# Out:
# TF-IDF Representation:
#    analytics  classification      data  documents  extracts       for  \
# 0   0.355964        0.000000  0.355964   0.000000  0.355964  0.000000
# 1   0.000000        0.363255  0.000000   0.000000  0.000000  0.363255
# 2   0.000000        0.000000  0.000000   0.423394  0.000000  0.000000
#
#        from  information        is  language  meaningful   natural  \
# 0  0.355964     0.270720  0.000000  0.000000    0.355964  0.000000
# 1  0.000000     0.000000  0.363255  0.363255    0.000000  0.363255
# 2  0.000000     0.322002  0.000000  0.000000    0.000000  0.000000
#
#    processing  relevant  retrieval    search   systems      text      used
# 0    0.000000  0.000000   0.000000  0.000000  0.000000  0.541440  0.000000
# 1    0.363255  0.000000   0.000000  0.000000  0.000000  0.276265  0.363255
# 2    0.000000  0.423394   0.423394  0.423394  0.423394  0.000000  0.000000
